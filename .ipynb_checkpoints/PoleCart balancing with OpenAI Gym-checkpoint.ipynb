# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)

# %%
for episode in range(1, 11):
    score = 0
    state = env.reset()
    done = False
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
        
    print('Episode:', episode, 'Score:', score)
    
env.close()
# Out:
# Episode: 1 Score: 11.0
# Episode: 2 Score: 17.0
# Episode: 3 Score: 10.0
# Episode: 4 Score: 47.0
# Episode: 5 Score: 59.0
# Episode: 6 Score: 18.0
# Episode: 7 Score: 16.0
# Episode: 8 Score: 22.0
# Episode: 9 Score: 38.0
# Episode: 10 Score: 22.0

# %%
#env = gym.make(env_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps = 50000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 249  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 2           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009326187 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00112     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.01        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 53.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 3           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009551637 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.082       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 39.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 4           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010310866 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0247     |
# |    value_loss           | 44.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 5           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008480556 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 64.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 6           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008074809 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 67.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 7           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005331058 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00963    |
# |    value_loss           | 43.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 8           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010210138 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.29        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 45.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 218          |
# |    iterations           | 9            |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0049068583 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.43         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00747     |
# |    value_loss           | 38.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 10          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005840374 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00781    |
# |    value_loss           | 52.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 11          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008311706 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.63        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00956    |
# |    value_loss           | 16          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 220          |
# |    iterations           | 12           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0046246443 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.549       |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.8         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00789     |
# |    value_loss           | 81.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 220          |
# |    iterations           | 13           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0082225455 |
# |    clip_fraction        | 0.0568       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.862        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 13.1         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 220        |
# |    iterations           | 14         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.00827577 |
# |    clip_fraction        | 0.0953     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.528     |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.05       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 5.44       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 220          |
# |    iterations           | 15           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0036544572 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.52        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.31         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 46.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 16          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009700842 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 5.1         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 220          |
# |    iterations           | 17           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0027190368 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.166        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00713     |
# |    value_loss           | 1.3          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 18          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012380678 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.505      |
# |    explained_variance   | -0.143      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0291      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.613       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 220          |
# |    iterations           | 19           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0068627344 |
# |    clip_fraction        | 0.0907       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.373        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0615       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00637     |
# |    value_loss           | 0.382        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 20          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004104185 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | -0.0232     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00172    |
# |    value_loss           | 0.243       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 220          |
# |    iterations           | 21           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0047850204 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.0927       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0149      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 0.147        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 220          |
# |    iterations           | 22           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0041152174 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.483       |
# |    explained_variance   | 0.0237       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00459     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000906    |
# |    value_loss           | 0.101        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 221          |
# |    iterations           | 23           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0038569164 |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.461       |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00664     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 0.0643       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 24          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.003040797 |
# |    clip_fraction        | 0.0217      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | 0.00765     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00336    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 0.0383      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 221          |
# |    iterations           | 25           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0057571307 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.455       |
# |    explained_variance   | 0.0234       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0113       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00247     |
# |    value_loss           | 0.0248       |
# ------------------------------------------
